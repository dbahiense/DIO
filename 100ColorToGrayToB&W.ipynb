# %% [markdown]
# <a href="https://colab.research.google.com/github/dbahiense/DIO/blob/main/100ColorToGrayToB%26W.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import necessary libraries
import cv2
from google.colab.patches import cv2_imshow

# %%
#load original image
original_image = cv2.imread('resources/images/len_full.jpg')

# %%
#transform original image to gray scale
gray_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2GRAY)

# %%
#threshold to set pixel black or white
(thresh, bw_image) = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY)

# %%
#show original, gray and b&w images
cv2_imshow(original_image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x855 at 0x7F9E8CD66B50>

# %%
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=400x855 at 0x7F9E8CD60C50>

# %%
cv2_imshow(bw_image)
# Out:
# <PIL.Image.Image image mode=L size=400x855 at 0x7F9E8CD60210>
